# %%
import re
import datetime
import pandas as pd

import numpy as np

import math
from itertools import cycle, islice
import matplotlib.pyplot as plt

import plotly.express as px

# %%
positionData = pd.read_csv('./logs/october22-2023-global-position.csv')
fig = px.scatter_3d(positionData, x="lat", y="lon", z="alt", hover_name="Time")
fig.show()
